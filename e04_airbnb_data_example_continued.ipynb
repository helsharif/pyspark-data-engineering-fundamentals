# %%
# Husayn El Sharif
comment = """
This script demonstrates basic operations using PySpark.
Using AirBnB dataset as an example.
use environment: spark4_env001"""

# %%
# imports

from pyspark.sql import SparkSession # Import SparkSession from PySpark. SQL module

import requests

# %%
# Download data from insideairbnb.com for Broward County - Florida - USA and download to folder "airbnb_data"
urls = [
    "https://data.insideairbnb.com/united-states/fl/broward-county/2025-09-26/data/listings.csv.gz",
    "https://data.insideairbnb.com/united-states/fl/broward-county/2025-09-26/data/calendar.csv.gz",
    "https://data.insideairbnb.com/united-states/fl/broward-county/2025-09-26/data/reviews.csv.gz",
    ]

# loop through the URLs and download each file, but check if file already exists
for url in urls:
    filename = url.split("/")[-1]
    try:
        with open(f"airbnb_data/{filename}", "rb") as f:
            print(f"{filename} already exists. Skipping download.")
    except FileNotFoundError:
        print(f"Downloading {filename}...")
        response = requests.get(url)
        with open(f"airbnb_data/{filename}", "wb") as f:
            f.write(response.content)
        print(f"Downloaded {filename}.")
# Out:
# listings.csv.gz already exists. Skipping download.
# calendar.csv.gz already exists. Skipping download.
# reviews.csv.gz already exists. Skipping download.

# %%
# Read Data in Spark Session
spark = SparkSession.builder.appName("AirBnB_Data_Example").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/12/25 10:18:14 WARN Utils: Your hostname, Husayn-SLS2, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/12/25 10:18:14 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/25 10:18:15 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Read Listings Data
listings_df = spark.read.csv("airbnb_data/listings.csv.gz", 
                             header=True, 
                             inferSchema=True, 
                             sep=",", 
                             quote='"', 
                             escape='"',  # Handle escaped quotes
                             multiLine=True, 
                             mode="PERMISSIVE")

# %%
# Select the review_scores_location column
review_locations = listings_df.select(listings_df.review_scores_location)
review_locations.show(20)
# Out:
# +----------------------+
# |review_scores_location|
# +----------------------+
# |                  4.88|
# |                   5.0|
# |                  4.82|
# |                  4.56|
# |                  4.87|
# |                  4.77|
# |                  4.88|
# |                   4.5|
# |                  4.68|
# |                  4.88|
# |                  4.72|
# |                  4.75|
# |                   5.0|
# |                  4.92|
# |                  4.88|
# |                  4.93|
# |                   3.5|
# |                  4.64|
# |                   5.0|
# |                   4.7|
# +----------------------+
# only showing top 20 rows

# %%
# chain of method calls
# drop rows with null values
review_locations_chained = (
    listings_df
    .filter(listings_df.review_scores_location > 4.5)
    .select('id', 'name', 'price','review_scores_location',)
    .dropna() # drop rows with null values
    .show(20, truncate=False)
                            )
# Out:
# +-------+--------------------------------------------------+-------+----------------------+
# |id     |name                                              |price  |review_scores_location|
# +-------+--------------------------------------------------+-------+----------------------+
# |69824  |2 bd/2ba Oceanfront Condo                         |$140.00|5.0                   |
# |129099 |MIAMI - AMAZING APARTMENT OCEANVIEW               |$234.00|4.56                  |
# |191160 |Tropical Beach Paradise Awaits You                |$119.00|4.87                  |
# |216046 |Dual Masters! - Adult Media/Game Rm - 1GB Internet|$247.00|4.77                  |
# |217990 |COSY APT OVER THE BEACH                           |$250.00|4.88                  |
# |256386 |Country Living for Four                           |$79.00 |4.68                  |
# |308839 |Fabulous & Private 475 sq ft Suite                |$75.00 |4.88                  |
# |325734 |Hidden Gem for two                                |$43.00 |4.72                  |
# |349538 |Fort Lauderdale Beach Resort - Excellent Location |$211.00|4.75                  |
# |366178 |Tropical Guest House - Heart of Ft. Lauderdale!   |$74.00 |4.92                  |
# |367815 |SPECTACULAR DIRECT OCEANFRONT VIEWS - Amazing     |$150.00|4.88                  |
# |393982 |Charming Comfort... Ft Lauderdale Home            |$82.00 |4.93                  |
# |484515 |MIAMI- AMAZING APARTMENT OVER BEACH               |$297.00|4.64                  |
# |1147098|Beachfront 2 Story/3BRM/3BA/2 O. View Ter./Parking|$170.00|4.95                  |
# |1176802|Tides beautiful ocean view condo-promotions       |$99.00 |4.93                  |
# |1305586|Oceanfront 1 Bedroom 2 Bath Penthouse             |$115.00|4.9                   |
# |1309185|Oceanfront 1bd/1br condo HOLLYWOOD BEACH          |$136.00|4.87                  |
# |1375343|Small House for two                               |$49.00 |4.67                  |
# |1376873|Beautiful Boutique Condo Steps from the Beach     |$178.00|4.92                  |
# |1548483|"Welcome home on Hallandale Beach"                |$201.00|4.75                  |
# +-------+--------------------------------------------------+-------+----------------------+
# only showing top 20 rows

# %%
# Find places with low price by high rating
listings_df.schema['price'] # price is currently a string, need to convert to float

from pyspark.sql.functions import regexp_replace, col
price_numeric = (
    listings_df
    .withColumn('price_numeric', regexp_replace(col('price'), '[$,]', '').cast('float'))
                )

price_numeric.schema['price_numeric'] # now price is float
# Out:
# StructField('price_numeric', FloatType(), True)

# %%
price_numeric.show()
# Out:
# 25/12/25 10:32:00 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +------+--------------------+--------------+------------+---------------+--------------------+--------------------+---------------------+--------------------+-------+--------------------+---------+----------+--------------------+--------------------+------------------+------------------+--------------------+-----------------+--------------------+--------------------+--------------------+-------------------+-------------------------+--------------------+--------------------+----------------------+--------------------+----------------------+----------------------------+----------+-----------+--------------------+---------------+------------+---------+--------------+--------+----+--------------------+-------+--------------+--------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------+----------------+---------------+---------------+---------------+----------------+---------------------+-----------------+---------------------+----------------------+----------------+--------------------+-------------------------+-----------------------+------------+-----------+--------------------+----------------------+-------------------------+---------------------+---------------------------+----------------------+-------------------+-------+----------------+------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+-----------------+-------------+
# |    id|         listing_url|     scrape_id|last_scraped|         source|                name|         description|neighborhood_overview|         picture_url|host_id|            host_url|host_name|host_since|       host_location|          host_about|host_response_time|host_response_rate|host_acceptance_rate|host_is_superhost|  host_thumbnail_url|    host_picture_url|  host_neighbourhood|host_listings_count|host_total_listings_count|  host_verifications|host_has_profile_pic|host_identity_verified|       neighbourhood|neighbourhood_cleansed|neighbourhood_group_cleansed|  latitude|  longitude|       property_type|      room_type|accommodates|bathrooms|bathrooms_text|bedrooms|beds|           amenities|  price|minimum_nights|maximum_nights|minimum_minimum_nights|maximum_minimum_nights|minimum_maximum_nights|maximum_maximum_nights|minimum_nights_avg_ntm|maximum_nights_avg_ntm|calendar_updated|has_availability|availability_30|availability_60|availability_90|availability_365|calendar_last_scraped|number_of_reviews|number_of_reviews_ltm|number_of_reviews_l30d|availability_eoy|number_of_reviews_ly|estimated_occupancy_l365d|estimated_revenue_l365d|first_review|last_review|review_scores_rating|review_scores_accuracy|review_scores_cleanliness|review_scores_checkin|review_scores_communication|review_scores_location|review_scores_value|license|instant_bookable|calculated_host_listings_count|calculated_host_listings_count_entire_homes|calculated_host_listings_count_private_rooms|calculated_host_listings_count_shared_rooms|reviews_per_month|price_numeric|
# +------+--------------------+--------------+------------+---------------+--------------------+--------------------+---------------------+--------------------+-------+--------------------+---------+----------+--------------------+--------------------+------------------+------------------+--------------------+-----------------+--------------------+--------------------+--------------------+-------------------+-------------------------+--------------------+--------------------+----------------------+--------------------+----------------------+----------------------------+----------+-----------+--------------------+---------------+------------+---------+--------------+--------+----+--------------------+-------+--------------+--------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------+----------------+---------------+---------------+---------------+----------------+---------------------+-----------------+---------------------+----------------------+----------------+--------------------+-------------------------+-----------------------+------------+-----------+--------------------+----------------------+-------------------------+---------------------+---------------------------+----------------------+-------------------+-------+----------------+------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+-----------------+-------------+
# | 57818|https://www.airbn...|20250926165812|  2025-09-27|previous scrape|50% OFF Monthly S...|3  Month stays ON...| Check-in window<b...|https://a0.muscac...| 275948|https://www.airbn...|  Von Inc|2010-11-01|       Hollywood, FL|I love my house.....|    within an hour|              100%|                100%|                t|https://a0.muscac...|https://a0.muscac...|                NULL|                  3|                        3|  ['email', 'phone']|                   t|                     t|Neighborhood high...|             Hollywood|                        NULL|  26.01859|   -80.1243|         Entire home|Entire home/apt|           4|     NULL|        1 bath|       2|NULL|["Wifi", "Single ...|   NULL|            94|           730|                    94|                    94|                   730|                   730|                  94.0|                 730.0|            NULL|               t|             23|             53|             83|             358|           2025-09-27|               60|                    0|                     0|              89|                   1|                        0|                   NULL|  2013-01-03| 2024-03-08|                4.64|                   4.7|                     4.63|                  5.0|                       4.97|                  4.88|                4.7|   NULL|               f|                             2|                                          2|                                           0|                                          0|             0.39|         NULL|
# | 69824|https://www.airbn...|20250926165812|  2025-09-27|    city scrape|2 bd/2ba Oceanfro...|                NULL|                 NULL|https://a0.muscac...| 351303|https://www.airbn...|    Tracy|2011-01-17|           Aldie, VA|                NULL|      within a day|               70%|                 25%|                f|https://a0.muscac...|https://a0.muscac...|                NULL|                  4|                        5|  ['email', 'phone']|                   t|                     t|                NULL|      Hallandale Beach|                        NULL|  25.97641|  -80.12052|        Entire condo|Entire home/apt|           6|      2.0|       2 baths|       2|   4|["Wifi", "Elevato...|$140.00|            30|           365|                    30|                    30|                   365|                   365|                  30.0|                 365.0|            NULL|               t|             30|             60|             90|             365|           2025-09-27|                4|                    0|                     0|              96|                   0|                        0|                      0|  2021-03-27| 2023-06-03|                 4.0|                   4.5|                      4.0|                 4.75|                       4.75|                   5.0|                4.5|   NULL|               f|                             2|                                          2|                                           0|                                          0|             0.07|        140.0|
# | 83449|https://www.airbn...|20250926165812|  2025-09-27|previous scrape|2 miles from the ...|Mary Pop Apartmen...| Residential neigh...|https://a0.muscac...| 454736|https://www.airbn...|      Jon|2011-03-21|     Dania Beach, FL| LOCATION,LOCATIO...|    within an hour|              100%|                 98%|                t|https://a0.muscac...|https://a0.muscac...|                NULL|                 18|                       21|  ['email', 'phone']|                   t|                     t|Neighborhood high...|           Dania Beach|                        NULL|  26.03392|  -80.14201|  Entire rental unit|Entire home/apt|           5|     NULL|        1 bath|       2|NULL|["Wifi", "Host gr...|   NULL|             7|            28|                     7|                     7|                    28|                    28|                   7.0|                  28.0|            NULL|               t|              0|              0|              0|               0|           2025-09-27|               34|                    2|                     0|               0|                   2|                       28|                   NULL|  2011-11-01| 2025-01-21|                4.79|                  4.88|                     4.85|                 4.94|                       4.91|                  4.82|               4.88|   NULL|               f|                            16|                                         16|                                           0|                                          0|              0.2|         NULL|
# |129099|https://www.airbn...|20250926165812|  2025-09-27|    city scrape|MIAMI - AMAZING A...|Modern oceanview ...|                 NULL|https://a0.muscac...| 637272|https://www.airbn...|   Bianca|2011-05-28|Buenos Aires, Arg...|Hope you have a n...|      within a day|               50%|                 33%|                f|https://a0.muscac...|https://a0.muscac...|   Sunny Isles Beach|                  9|                       19|  ['email', 'phone']|                   t|                     t|                NULL|             Hollywood|                        NULL|  25.99414|  -80.11814|        Entire condo|Entire home/apt|           5|      1.5|     1.5 baths|       1|   3|["Pack \u2019n pl...|$234.00|            10|           365|                    10|                    10|                   365|                   365|                  10.0|                 365.0|            NULL|               t|             30|             60|             90|             275|           2025-09-27|               28|                    0|                     0|              96|                   1|                        0|                      0|  2011-08-23| 2024-03-14|                4.32|                  4.44|                     4.27|                 4.46|                       4.35|                  4.56|               4.12|   NULL|               f|                             5|                                          5|                                           0|                                          0|             0.16|        234.0|
# |191160|https://www.airbn...|20250926165812|  2025-09-27|    city scrape|Tropical Beach Pa...|Imagine being one...|                 NULL|https://a0.muscac...| 924482|https://www.airbn...|      Dan|2011-08-05| Fort Lauderdale, FL|I have built the ...|               N/A|               N/A|                  0%|                f|https://a0.muscac...|https://a0.muscac...|                NULL|                  2|                        3|  ['email', 'phone']|                   t|                     f|                NULL|       Deerfield Beach|                        NULL|  26.30707|  -80.07793|  Entire rental unit|Entire home/apt|           4|      1.0|        1 bath|       1|   2|["Wifi", "Host gr...|$119.00|             2|           180|                     2|                     2|                   180|                   180|                   2.0|                 180.0|            NULL|               t|             30|             60|             90|             179|           2025-09-27|               25|                    0|                     0|              96|                   0|                        0|                      0|  2012-01-04| 2019-11-08|                4.25|                  4.39|                     4.46|                 4.83|                       4.87|                  4.87|               4.43|   NULL|               f|                             1|                                          1|                                           0|                                          0|             0.15|        119.0|
# |216046|https://www.airbn...|20250926165812|  2025-09-27|    city scrape|Dual Masters! - A...|Rest assured that...| Nice quiet reside...|https://a0.muscac...| 964836|https://www.airbn...|     Gary|2011-08-13|       Hollywood, FL|Gary & Myriam liv...|within a few hours|              100%|                 94%|                t|https://a0.muscac...|https://a0.muscac...|                NULL|                  1|                        2|  ['email', 'phone']|                   t|                     t|Neighborhood high...|             Hollywood|                        NULL|   26.0077|  -80.19722|         Entire home|Entire home/apt|           8|      3.0|       3 baths|       4|   7|["Pack \u2019n pl...|$247.00|             2|            21|                     2|                     2|                  1125|                  1125|                   2.0|                1125.0|            NULL|               t|             10|             26|             41|             213|           2025-09-27|              121|                    8|                     1|              41|                   8|                       48|                  11856|  2012-01-02| 2025-09-01|                4.81|                  4.79|                     4.81|                 4.91|                       4.79|                  4.77|               4.76|   NULL|               f|                             1|                                          1|                                           0|                                          0|             0.72|        247.0|
# |217990|https://www.airbn...|20250926165812|  2025-09-27|    city scrape|COSY APT OVER THE...|                NULL|                 NULL|https://a0.muscac...| 637272|https://www.airbn...|   Bianca|2011-05-28|Buenos Aires, Arg...|Hope you have a n...|      within a day|               50%|                 33%|                f|https://a0.muscac...|https://a0.muscac...|   Sunny Isles Beach|                  9|                       19|  ['email', 'phone']|                   t|                     t|                NULL|             Hollywood|                        NULL|  25.99398|  -80.11677|  Entire rental unit|Entire home/apt|           5|      1.5|     1.5 baths|       1|   3|["Hair dryer", "W...|$250.00|            10|           365|                    10|                    10|                   365|                   365|                  10.0|                 365.0|            NULL|               t|             30|             60|             90|             365|           2025-09-27|               18|                    0|                     0|              96|                   0|                        0|                      0|  2011-11-21| 2018-03-19|                4.93|                  4.88|                     4.81|                  5.0|                        5.0|                  4.88|               4.81|   NULL|               f|                             5|                                          5|                                           0|                                          0|             0.11|        250.0|
# |241944|https://www.airbn...|20250926165812|  2025-09-27|previous scrape|Mary Pop Apartmen...|1 BEDROOM APARTME...|                 NULL|https://a0.muscac...| 454736|https://www.airbn...|      Jon|2011-03-21|     Dania Beach, FL| LOCATION,LOCATIO...|    within an hour|              100%|                 98%|                t|https://a0.muscac...|https://a0.muscac...|                NULL|                 18|                       21|  ['email', 'phone']|                   t|                     t|                NULL|           Dania Beach|                        NULL|  26.03392|  -80.14201|  Entire rental unit|Entire home/apt|           3|     NULL|        1 bath|       1|NULL|["Shampoo", "Hair...|   NULL|             7|            28|                     7|                     7|                    28|                    28|                   7.0|                  28.0|            NULL|               t|              0|              0|              0|               0|           2025-09-27|               14|                    0|                     0|               0|                   1|                        0|                   NULL|  2012-07-28| 2024-01-08|                4.54|                  4.43|                     4.43|                 4.79|                       4.93|                   4.5|                4.5|   NULL|               f|                            16|                                         16|                                           0|                                          0|             0.09|         NULL|
# |256386|https://www.airbn...|20250926165812|  2025-09-27|    city scrape|Country Living fo...|What a great plac...|                 NULL|https://a0.muscac...|1304156|https://www.airbn...|  Nicolas|2011-10-17|       Hollywood, FL|                NULL|    within an hour|               92%|                 98%|                t|https://a0.muscac...|https://a0.muscac...|                NULL|                  7|                       10|  ['email', 'phone']|                   t|                     t|                NULL|             Hollywood|                        NULL|  26.02584|  -80.14191|         Entire home|Entire home/apt|           4|      1.0|        1 bath|       2|   2|["Free driveway p...| $79.00|             2|           365|                     2|                     2|                   365|                   365|                   2.0|                 365.0|            NULL|               t|             13|             43|             73|             298|           2025-09-27|              298|                   29|                     0|              79|                  29|                      174|                  13746|  2012-01-02| 2025-08-24|                4.85|                   4.9|                     4.89|                 4.93|                       4.92|                  4.68|                4.8|   NULL|               f|                             4|                                          4|                                           0|                                          0|             1.78|         79.0|
# |308839|https://www.airbn...|20250926165812|  2025-09-27|    city scrape|Fabulous & Privat...|A spacious fully ...| You will experien...|https://a0.muscac...|1585064|https://www.airbn...|  Deborah|2012-01-09|         Miramar, FL|I love to share c...|               N/A|               N/A|                100%|                f|https://a0.muscac...|https://a0.muscac...|                NULL|                  2|                        3|['email', 'phone'...|                   t|                     t|Neighborhood high...|               Miramar|                        NULL|  25.98766|  -80.31598|Private room in g...|   Private room|           2|      1.0|1 private bath|       1|   1|["Wifi", "Private...| $75.00|           184|           333|                   181|                   184|                   305|                   333|                 182.2|                 316.4|            NULL|               t|             28|             58|             77|             251|           2025-09-27|               49|                    0|                     0|              77|                   0|                        0|                      0|  2012-03-13| 2023-02-25|                4.96|                  4.96|                     4.94|                  4.9|                       4.98|                  4.88|               4.84|   NULL|               f|                             2|                                          0|                                           2|                                          0|              0.3|         75.0|
# |325734|https://www.airbn...|20250926165812|  2025-09-27|    city scrape|  Hidden Gem for two|Studio apt with f...| Every thing is cl...|https://a0.muscac...|1304156|https://www.airbn...|  Nicolas|2011-10-17|       Hollywood, FL|                NULL|    within an hour|               92%|                 98%|                t|https://a0.muscac...|https://a0.muscac...|                NULL|                  7|                       10|  ['email', 'phone']|                   t|                     t|Neighborhood high...|             Hollywood|                        NULL|   26.0257|  -80.14105|         Entire home|Entire home/apt|           2|      1.0|        1 bath|       0|   1|["Single level ho...| $43.00|             2|           365|                     2|                     2|                   365|                   365|                   2.0|                 365.0|            NULL|               t|             28|             58|             88|             363|           2025-09-27|              253|                   25|                     0|              94|                  20|                      150|                   6450|  2013-02-14| 2025-08-25|                 4.8|                  4.82|                     4.91|                 4.88|                       4.88|                  4.72|               4.75|   NULL|               f|                             4|                                          4|                                           0|                                          0|             1.65|         43.0|
# |349538|https://www.airbn...|20250926165812|  2025-09-27|    city scrape|Fort Lauderdale B...|The Fort Lauderda...| The property is w...|https://a0.muscac...|1770887|https://www.airbn...|    Chris|2012-02-18|        Clermont, FL|My name is Chris ...|    within an hour|              100%|                 97%|                t|https://a0.muscac...|https://a0.muscac...|             Baristo|                522|                      580|['email', 'phone'...|                   t|                     t|Neighborhood high...|       Fort Lauderdale|                        NULL|26.1369065|-80.1051716|        Entire condo|Entire home/apt|           6|      1.0|        1 bath|       1|   3|["Wifi", "Elevato...|$211.00|             1|            30|                     1|                     7|                     7|                    30|                   3.1|                  20.3|            NULL|               t|             28|             58|             82|             159|           2025-09-27|               42|                    4|                     0|              87|                   5|                       24|                   5064|  2012-05-29| 2025-04-19|                4.73|                  4.85|                     4.88|                 4.55|                       4.82|                  4.75|               4.68|   NULL|               f|                            23|                                         23|                                           0|                                          0|             0.26|        211.0|
# |349546|https://www.airbn...|20250926165812|  2025-09-27|previous scrape|Fort Lauderdale B...|The Fort Lauderda...| The property is w...|https://a0.muscac...|1770887|https://www.airbn...|    Chris|2012-02-18|        Clermont, FL|My name is Chris ...|    within an hour|              100%|                 97%|                t|https://a0.muscac...|https://a0.muscac...|             Baristo|                522|                      580|['email', 'phone'...|                   t|                     t|Neighborhood high...|       Fort Lauderdale|                        NULL|  26.13684|  -80.10506|        Entire condo|Entire home/apt|           2|     NULL|        1 bath|    NULL|NULL|["Wifi", "Elevato...|   NULL|             1|            30|                     1|                     7|                     7|                    30|                   2.0|                  24.3|            NULL|               t|             28|             58|             82|              89|           2025-09-27|                9|                    4|                     0|              82|                   1|                       24|                   NULL|  2013-04-04| 2025-03-08|                4.56|                  4.25|                     4.63|                 4.63|                       4.88|                   5.0|               4.63|   NULL|               f|                            23|                                         23|                                           0|                                          0|             0.06|         NULL|
# |366178|https://www.airbn...|20250926165812|  2025-09-27|    city scrape|Tropical Guest Ho...|Enjoy south Flori...| *VICTORIA PARK......|https://a0.muscac...|1848829|https://www.airbn...|    Boris|2012-03-03| Fort Lauderdale, FL|Over the years my...|    within an hour|              100%|                 91%|                t|https://a0.muscac...|https://a0.muscac...|       Victoria Park|                  3|                        3|  ['email', 'phone']|                   t|                     t|Neighborhood high...|       Fort Lauderdale|                        NULL|  26.12683|  -80.13549|         Entire home|Entire home/apt|           2|      1.0|        1 bath|       1|   1|["Wifi", "Single ...| $74.00|             7|           365|                     7|                     7|                   365|                   365|                   7.0|                 365.0|            NULL|               t|             30|             60|             65|             214|           2025-09-27|               62|                   14|                     0|              65|                  14|                      196|                  14504|  2012-05-17| 2025-06-30|                4.82|                  4.87|                     4.72|                 4.93|                        5.0|                  4.92|               4.84|   NULL|               f|                             3|                                          3|                                           0|                                          0|             0.38|         74.0|
# |367815|https://www.airbn...|20250926165812|  2025-09-27|    city scrape|SPECTACULAR DIREC...|3 MONTHS or MORE ...| Restaurants, supe...|https://a0.muscac...| 238902|https://www.airbn...|    Wanda|2010-09-19|Florida, United S...|We're from Florid...|               N/A|               N/A|                 N/A|                f|https://a0.muscac...|https://a0.muscac...|Hollywood South C...|                  2|                        2|           ['phone']|                   t|                     t|Neighborhood high...|             Hollywood|                        NULL|  26.00741|  -80.11596|        Entire condo|Entire home/apt|           3|      1.0|        1 bath|       1|   3|["Wifi", "Elevato...|$150.00|            90|          3650|                    90|                    90|                  3650|                  3650|                  90.0|                3650.0|            NULL|               t|             23|             53|             83|             358|           2025-09-27|                8|                    0|                     0|              89|                   0|                        0|                      0|  2012-04-15| 2019-04-01|                 5.0|                   5.0|                      5.0|                 4.88|                       4.88|                  4.88|               4.88|   NULL|               f|                             1|                                          1|                                           0|                                          0|             0.05|        150.0|
# |393982|https://www.airbn...|20250926165812|  2025-09-27|    city scrape|Charming Comfort....|South-Florida cha...| *VICTORIA PARK......|https://a0.muscac...|1848829|https://www.airbn...|    Boris|2012-03-03| Fort Lauderdale, FL|Over the years my...|    within an hour|              100%|                 91%|                t|https://a0.muscac...|https://a0.muscac...|       Victoria Park|                  3|                        3|  ['email', 'phone']|                   t|                     t|Neighborhood high...|       Fort Lauderdale|                        NULL|  26.12676|  -80.13657|         Entire home|Entire home/apt|           2|      1.0|        1 bath|       1|   1|["Wifi", "Private...| $82.00|             7|           365|                     7|                     7|                   365|                   365|                   7.0|                 365.0|            NULL|               t|              5|             32|             50|             235|           2025-09-27|               40|                    4|                     0|              56|                   8|                       56|                   4592|  2012-06-18| 2025-05-29|                4.85|                  4.78|                      4.8|                 4.98|                       4.98|                  4.93|               4.85|   NULL|               f|                             3|                                          3|                                           0|                                          0|             0.25|         82.0|
# |436596|https://www.airbn...|20250926165812|  2025-09-27|previous scrape|Beautiful Water F...|My Beautiful Wate...| My house is on a ...|https://a0.muscac...|2168585|https://www.airbn...|      Lou|2012-04-18|        New York, NY|I am a Pilates Te...|a few days or more|                0%|                 N/A|                f|https://a0.muscac...|https://a0.muscac...|                NULL|                  1|                        2|  ['email', 'phone']|                   t|                     f|Neighborhood high...|         Pompano Beach|                        NULL|  26.21709|  -80.12193|         Entire home|Entire home/apt|           6|     NULL|       3 baths|       3|NULL|["Wifi", "Private...|   NULL|             7|           365|                     7|                     7|                   365|                   365|                   7.0|                 365.0|            NULL|               t|             28|             58|             88|             363|           2025-09-27|                2|                    0|                     0|              94|                   0|                        0|                   NULL|  2014-04-09| 2015-01-06|                 4.0|                   3.5|                      3.0|                  5.0|                        5.0|                   3.5|                2.5|   NULL|               f|                             1|                                          1|                                           0|                                          0|             0.01|         NULL|
# |484515|https://www.airbn...|20250926165812|  2025-09-27|    city scrape|MIAMI- AMAZING AP...|                NULL|                 NULL|https://a0.muscac...| 637272|https://www.airbn...|   Bianca|2011-05-28|Buenos Aires, Arg...|Hope you have a n...|      within a day|               50%|                 33%|                f|https://a0.muscac...|https://a0.muscac...|   Sunny Isles Beach|                  9|                       19|  ['email', 'phone']|                   t|                     t|                NULL|             Hollywood|                        NULL|  25.99276|  -80.11819|        Entire condo|Entire home/apt|           7|      2.0|       2 baths|       2|   4|["Hair dryer", "W...|$297.00|             7|          1125|                     7|                     7|                  1125|                  1125|                   7.0|                1125.0|            NULL|               t|             29|             59|             89|             364|           2025-09-27|               25|                    0|                     0|              95|                   0|                        0|                      0|  2012-07-14| 2021-03-19|                4.61|                  4.88|                     4.48|                 4.76|                        4.6|                  4.64|               4.44|   NULL|               f|                             5|                                          5|                                           0|                                          0|             0.16|        297.0|
# |533847|https://www.airbn...|20250926165812|  2025-09-27|previous scrape|Private, Tranquil...|This private cozy...| You will experien...|https://a0.muscac...|1585064|https://www.airbn...|  Deborah|2012-01-09|         Miramar, FL|I love to share c...|               N/A|               N/A|                100%|                f|https://a0.muscac...|https://a0.muscac...|                NULL|                  2|                        3|['email', 'phone'...|                   t|                     t|Neighborhood high...|               Miramar|                        NULL|  25.98653|  -80.31554|Private room in g...|   Private room|           2|     NULL|1 private bath|       1|NULL|["Wifi", "Free dr...|   NULL|           184|           333|                   181|                   184|                   305|                   333|                 182.2|                 316.4|            NULL|               t|              0|              0|              9|             284|           2025-09-27|               50|                    1|                     0|              15|                   3|                      255|                   NULL|  2012-09-09| 2024-11-17|                 5.0|                  4.98|                     4.96|                  5.0|                        5.0|                   5.0|                5.0|   NULL|               f|                             2|                                          0|                                           2|                                          0|             0.31|         NULL|
# |592583|https://www.airbn...|20250926165812|  2025-09-27|previous scrape|Fort Lauderdale B...|The Fort Lauderda...| The property is w...|https://a0.muscac...|1770887|https://www.airbn...|    Chris|2012-02-18|        Clermont, FL|My name is Chris ...|    within an hour|              100%|                 97%|                t|https://a0.muscac...|https://a0.muscac...|             Baristo|                522|                      580|['email', 'phone'...|                   t|                     t|Neighborhood high...|       Fort Lauderdale|                        NULL|26.1369065|-80.1051716|        Entire condo|Entire home/apt|           8|     NULL|       2 baths|       2|NULL|["Wifi", "Elevato...|   NULL|             1|            30|                     1|                     7|                     7|                    30|                   1.5|                  28.2|            NULL|               t|              0|              4|              7|              28|           2025-09-27|               31|                    1|                     0|               7|                   2|                        6|                   NULL|  2012-09-20| 2025-03-08|                4.76|                   4.8|                      4.8|                 4.77|                       4.83|                   4.7|               4.67|   NULL|               f|                            23|                                         23|                                           0|                                          0|              0.2|         NULL|
# +------+--------------------+--------------+------------+---------------+--------------------+--------------------+---------------------+--------------------+-------+--------------------+---------+----------+--------------------+--------------------+------------------+------------------+--------------------+-----------------+--------------------+--------------------+--------------------+-------------------+-------------------------+--------------------+--------------------+----------------------+--------------------+----------------------+----------------------------+----------+-----------+--------------------+---------------+------------+---------+--------------+--------+----+--------------------+-------+--------------+--------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------+----------------+---------------+---------------+---------------+----------------+---------------------+-----------------+---------------------+----------------------+----------------+--------------------+-------------------------+-----------------------+------------+-----------+--------------------+----------------------+-------------------------+---------------------+---------------------------+----------------------+-------------------+-------+----------------+------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+-----------------+-------------+
# only showing top 20 rows

# %%
# Find "hidden gems" - high rating and low price
hidden_gems = (
    price_numeric
    .filter((price_numeric.review_scores_location >= 4.5) & (price_numeric.price_numeric <= 100))
    .select('id', 'name', 'price_numeric', 'review_scores_location')
    .distinct()
    .sort(col('price_numeric').asc(), col('review_scores_location').desc())
    .show(20, truncate=False)
)
# Out:
# +-------------------+--------------------------------------------------+-------------+----------------------+
# |id                 |name                                              |price_numeric|review_scores_location|
# +-------------------+--------------------------------------------------+-------------+----------------------+
# |1407434945159519189|Fuego Flame Shared Room | Cozy Vibes + Wi-Fi      |17.0         |5.0                   |
# |1411601831397814339|Cactus Sunset Stay | Snug Shared Room + Wi-Fi     |20.0         |5.0                   |
# |1080465942036472771|Marriott's BeachPlace Towers - 2BR Waterview Villa|22.0         |5.0                   |
# |1082128443548644880|Marriott's BeachPlace Towers - 2BR Waterview Villa|22.0         |5.0                   |
# |1085532924382363878|Marriott's BeachPlace Towers - Waterview Studio   |22.0         |5.0                   |
# |1313333889280898230|Cozy Shared Room near Beach                       |23.0         |4.78                  |
# |1485724200696175067|G4 master bath TV                                 |27.0         |5.0                   |
# |1329016742028017066|MIXED DORM Cozy budget-friendly hostel stay       |28.0         |4.53                  |
# |1496766840327893302|A Single Bed in Shared Male Dorm                  |29.0         |4.71                  |
# |970927431737808360 |Cozy room in cute beach cottage!                  |29.0         |4.62                  |
# |1366081966983441625|Comfortable Hostel in Hollywood!                  |29.0         |4.5                   |
# |1315984655683950196|DB2) Cozy shared room/airport                     |30.0         |5.0                   |
# |1315990360758402717|DF1)Shared room/girls only/port nearby            |30.0         |5.0                   |
# |987555666919368775 |Affordable Private Room                           |30.0         |5.0                   |
# |1411678793110656120|Desert Calm by Cactus | Comfortable + Wi-Fi       |30.0         |5.0                   |
# |16174775           |Modern room in convenient location!               |30.0         |4.94                  |
# |53583846           |Small basic but cozy room, free parking.          |30.0         |4.73                  |
# |24605244           |Cosas Geniales  y Bonitas                         |30.0         |4.65                  |
# |1370566256624346758|Have Other Rooms Avai Chat Me Long Term 6 month 1d|31.0         |5.0                   |
# |1303199581578620356|Share BedR Closet Share Full Kichen&BathR Laundry |31.0         |5.0                   |
# +-------------------+--------------------------------------------------+-------------+----------------------+
# only showing top 20 rows

# %%
# write the ouptut file to csv
hidden_gems = (
    price_numeric
    .filter((price_numeric.review_scores_location >= 4.5) & (price_numeric.price_numeric <= 100))
    .select('id', 'name', 'price_numeric', 'review_scores_location')
    .distinct()
    .sort(col('price_numeric').asc(), col('review_scores_location').desc())
)

hidden_gems.write.csv("airbnb_data/hidden_gems", header=True)

# %%
spark.stop()  # Stop the Spark session when done
